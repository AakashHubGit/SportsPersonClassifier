# %%
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/msd (4).jpg')
img.shape
# Out:
# (1600, 1298, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1600, 1298)

# %%
gray
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[239, 259, 573, 573]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (239, 259, 573, 573)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print("Error: Unable to load image at", image_path)
        return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/virat.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/virat.jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/hardik_pandya',
#  './dataset/ms_dhoni',
#  './dataset/rohit_sharma',
#  './dataset/sachin_tendulkar',
#  './dataset/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/hardik_pandya
# Generating cropped images in folder:  ./dataset/cropped/ms_dhoni
# Generating cropped images in folder:  ./dataset/cropped/rohit_sharma
# Generating cropped images in folder:  ./dataset/cropped/sachin_tendulkar
# Generating cropped images in folder:  ./dataset/cropped/virat_kohli

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'hardik_pandya': ['./dataset/cropped/hardik_pandya\\hardik_pandya1.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya10.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya11.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya12.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya13.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya14.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya15.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya16.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya17.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya18.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya19.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya2.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya20.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya21.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya22.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya23.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya24.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya25.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya27.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya28.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya29.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya3.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya31.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya32.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya33.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya35.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya37.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya38.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya39.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya4.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya40.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya41.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya42.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya43.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya44.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya45.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya46.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya47.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya48.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya49.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya5.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya50.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya51.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya52.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya53.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya54.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya6.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya7.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya8.png',
#   './dataset/cropped/hardik_pandya\\hardik_pandya9.png'],
#  'ms_dhoni': ['./dataset/cropped/ms_dhoni\\ms_dhoni1.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni10.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni11.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni14.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni15.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni17.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni18.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni19.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni2.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni20.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni21.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni22.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni23.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni24.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni25.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni26.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni27.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni3.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni30.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni31.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni32.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni33.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni34.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni35.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni36.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni37.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni38.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni39.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni4.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni40.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni5.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni6.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni7.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni8.png',
#   './dataset/cropped/ms_dhoni\\ms_dhoni9.png'],
#  'rohit_sharma': ['./dataset/cropped/rohit_sharma\\rohit_sharma1.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma10.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma11.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma12.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma13.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma14.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma15.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma16.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma17.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma18.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma19.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma2.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma21.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma22.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma23.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma25.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma27.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma3.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma4.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma5.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma7.png',
#   './dataset/cropped/rohit_sharma\\rohit_sharma9.png'],
#  'sachin_tendulkar': ['./dataset/cropped/sachin_tendulkar\\sachin_tendulkar1.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar10.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar11.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar13.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar14.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar16.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar17.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar18.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar19.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar2.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar20.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar21.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar22.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar23.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar24.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar25.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar26.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar27.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar28.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar29.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar3.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar30.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar31.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar32.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar33.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar34.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar35.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar36.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar37.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar38.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar39.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar4.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar41.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar42.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar43.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar44.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar45.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar46.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar47.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar48.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar49.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar5.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar6.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar8.png',
#   './dataset/cropped/sachin_tendulkar\\sachin_tendulkar9.png'],
#  'virat_kohli': ['./dataset/cropped/virat_kohli\\virat_kohli1.png',
#   './dataset/cropped/virat_kohli\\virat_kohli10.png',
#   './dataset/cropped/virat_kohli\\virat_kohli11.png',
#   './dataset/cropped/virat_kohli\\virat_kohli12.png',
#   './dataset/cropped/virat_kohli\\virat_kohli13.png',
#   './dataset/cropped/virat_kohli\\virat_kohli14.png',
#   './dataset/cropped/virat_kohli\\virat_kohli15.png',
#   './dataset/cropped/virat_kohli\\virat_kohli16.png',
#   './dataset/cropped/virat_kohli\\virat_kohli18.png',
#   './dataset/cropped/virat_kohli\\virat_kohli19.png',
#   './dataset/cropped/virat_kohli\\virat_kohli2.png',
#   './dataset/cropped/virat_kohli\\virat_kohli20.png',
#   './dataset/cropped/virat_kohli\\virat_kohli21.png',
#   './dataset/cropped/virat_kohli\\virat_kohli22.png',
#   './dataset/cropped/virat_kohli\\virat_kohli23.png',
#   './dataset/cropped/virat_kohli\\virat_kohli24.png',
#   './dataset/cropped/virat_kohli\\virat_kohli25.png',
#   './dataset/cropped/virat_kohli\\virat_kohli27.png',
#   './dataset/cropped/virat_kohli\\virat_kohli29.png',
#   './dataset/cropped/virat_kohli\\virat_kohli3.png',
#   './dataset/cropped/virat_kohli\\virat_kohli30.png',
#   './dataset/cropped/virat_kohli\\virat_kohli31.png',
#   './dataset/cropped/virat_kohli\\virat_kohli32.png',
#   './dataset/cropped/virat_kohli\\virat_kohli33.png',
#   './dataset/cropped/virat_kohli\\virat_kohli34.png',
#   './dataset/cropped/virat_kohli\\virat_kohli35.png',
#   './dataset/cropped/virat_kohli\\virat_kohli36.png',
#   './dataset/cropped/virat_kohli\\virat_kohli39.png',
#   './dataset/cropped/virat_kohli\\virat_kohli4.png',
#   './dataset/cropped/virat_kohli\\virat_kohli40.png',
#   './dataset/cropped/virat_kohli\\virat_kohli41.png',
#   './dataset/cropped/virat_kohli\\virat_kohli42.png',
#   './dataset/cropped/virat_kohli\\virat_kohli43.png',
#   './dataset/cropped/virat_kohli\\virat_kohli44.png',
#   './dataset/cropped/virat_kohli\\virat_kohli45.png',
#   './dataset/cropped/virat_kohli\\virat_kohli46.png',
#   './dataset/cropped/virat_kohli\\virat_kohli47.png',
#   './dataset/cropped/virat_kohli\\virat_kohli48.png',
#   './dataset/cropped/virat_kohli\\virat_kohli49.png',
#   './dataset/cropped/virat_kohli\\virat_kohli51.png',
#   './dataset/cropped/virat_kohli\\virat_kohli52.png',
#   './dataset/cropped/virat_kohli\\virat_kohli53.png',
#   './dataset/cropped/virat_kohli\\virat_kohli6.png',
#   './dataset/cropped/virat_kohli\\virat_kohli7.png',
#   './dataset/cropped/virat_kohli\\virat_kohli8.png',
#   './dataset/cropped/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'hardik_pandya': 0,
#  'ms_dhoni': 1,
#  'rohit_sharma': 2,
#  'sachin_tendulkar': 3,
#  'virat_kohli': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 198

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (198, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.74

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.77      0.74        13
#            1       0.67      0.75      0.71         8
#            2       1.00      0.50      0.67         4
#            3       0.86      0.80      0.83        15
#            4       0.64      0.70      0.67        10
#
#     accuracy                           0.74        50
#    macro avg       0.77      0.70      0.72        50
# weighted avg       0.76      0.74      0.74        50

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=10, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.775238
# 1        random_forest    0.506667
# 2  logistic_regression    0.774762
#
#                                    best_params
# 0       {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 5}
# 2                 {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=5))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.58

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[12,  0,  1,  0,  0],
#        [ 2,  6,  0,  0,  0],
#        [ 0,  0,  3,  1,  0],
#        [ 1,  1,  0, 12,  1],
#        [ 1,  1,  0,  1,  7]], dtype=int64)

# %%
class_dict
# Out:
# {'hardik_pandya': 0,
#  'ms_dhoni': 1,
#  'rohit_sharma': 2,
#  'sachin_tendulkar': 3,
#  'virat_kohli': 4}

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
